# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
# Get list of Application Types
index_list = [x for x in application_df["APPLICATION_TYPE"].value_counts().index]

# get list of number of application types
app_list = [x for x in application_df["APPLICATION_TYPE"].value_counts()]

application_types_to_replace=[]

# Set cutoff to 500
cutoff = 500

# Loop through aplication types list and if the total number is lower than cutoff
# add it to application_types_to_replace
for x in range(len(app_list)):
  if app_list[x] < cutoff:
    application_types_to_replace.append(index_list[x])

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts().loc[lambda x: x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
# Get list of Classifications
index_list = [x for x in application_df["CLASSIFICATION"].value_counts().index]

# get list of number of classifications
cls_list = [x for x in application_df["CLASSIFICATION"].value_counts()]

classifications_to_replace=[]

# Set cutoff to 1800
cutoff = 1800

# Loop through classifications list and if the total number is lower than cutoff
# add it to classifications_to_replace
for x in range(len(cls_list)):
  if cls_list[x] < cutoff:
    classifications_to_replace.append(index_list[x])

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Attempt to optimize by removing columns from dataframe

application_df = application_df.drop(columns=["STATUS", "SPECIAL_CONSIDERATIONS"])

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y= application_df["IS_SUCCESSFUL"]
X = application_df.drop(columns="IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X
# Out:
#         ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0          5000                       0                     1
# 1        108590                       0                     0
# 2          5000                       0                     0
# 3          6692                       0                     0
# 4        142590                       0                     0
# ...         ...                     ...                   ...
# 34294      5000                       0                     0
# 34295      5000                       0                     0
# 34296      5000                       0                     0
# 34297      5000                       0                     0
# 34298  36500179                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# 1                         0                    1                    0
# ...

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

number_input_features = 40
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 40

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 80)                3280
#
#  dense_4 (Dense)             (None, 40)                3240
#
#  dense_5 (Dense)             (None, 1)                 41
#
# ...
# Total params: 6,561
# Trainable params: 6,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5698 - accuracy: 0.7198
# Epoch 2/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5555 - accuracy: 0.7285
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5521 - accuracy: 0.7280
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7302
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7332
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7318
# Epoch 7/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5481 - accuracy: 0.7320
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7326
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7331
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5524 - accuracy: 0.7290 - 710ms/epoch - 3ms/step
# Loss: 0.5524064302444458, Accuracy: 0.7289795875549316

# %%
# Export our model to HDF5 file

nn.save("AlphabetSoupCharity_Optimization.h5", save_format='h5')
